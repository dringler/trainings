# %% [markdown]
# # Access Web APIs with Python
#
# Some good tutorials of how to get started with accessing Web APIs with Python are the following:
# * https://www.dataquest.io/blog/python-api-tutorial/
# * https://www.digitalocean.com/community/tutorials/how-to-use-web-apis-in-python-3

# %% [markdown]
# # Requests
# HTTP library for Python.
#
# See https://2.python-requests.org/en/master/ for the official documentation and https://github.com/kennethreitz/requests for the GitHub repository.
#
# To install requests, run the following command in your terminal:
#
# ```bash
# # conda install -c anaconda requests
# ```
#
# Example request:
#
# ```python
# >>> import requests
# >>> r = requests.get('https://api.github.com/user', auth=('user', 'pass'))
# >>> r.status_code
# 200
# >>> r.headers['content-type']
# 'application/json; charset=utf8'
# >>> r.encoding
# 'utf-8'
# >>> r.text
# u'{"type":"User"...'
# >>> r.json()
# {u'private_gists': 419, u'total_private_repos': 77, ...}
# ```
#
# ## Example of using the Genius API

# %%
# https://github.com/emilkloeden/py-genius/blob/master/py_genius/py_genius.py
import requests
import json
import urllib3
import certifi
from bs4 import BeautifulSoup

def getTokens():
    with open('/home/dan/genius_token.txt') as f:
        return f.read().splitlines()

class Genius(object):
    def __init__(self, access_token):
        self.auth = {'Authorization': "Bearer {}".format(access_token)}
        self.prefix = "https://api.genius.com"
    
    def __queryGenius(self, method, url, q):
        http = urllib3.PoolManager(cert_reqs='CERT_REQUIRED', ca_certs=certifi.where())
        r = http.request(method, url, headers=self.auth, fields=q)
        if r.status == 200:
            return json.loads(r.data.decode('utf-8'))
        else:
            print(r.status)
        
    def search(self, searchTerm):     
        url = self.prefix + "/search"
        q = {"q": searchTerm}    
        return self.__queryGenius("GET", url, q)
        

# get access token
accessToken = getTokens()
# open connection to API
g = Genius(accessToken[0])
# send search request
g.search("radiohead")
# Out:
# {'meta': {'status': 200},
#  'response': {'hits': [{'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 8,
#      'api_path': '/songs/109096',
#      'full_title': 'Creep by\xa0Radiohead',
#      'header_image_thumbnail_url': 'https://images.genius.com/7e8ec7d3265b0867ba38e232650f7c82.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/7e8ec7d3265b0867ba38e232650f7c82.1000x1000x1.jpg',
#      'id': 109096,
#      'lyrics_owner_id': 116340,
#      'lyrics_state': 'complete',
#      'path': '/Radiohead-creep-lyrics',
#      'pyongs_count': 174,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/542fbb949a17a83a6375e15e39e1253c.300x300x1.jpg',
#      'stats': {'unreviewed_annotations': 1,
#       'concurrents': 7,
#       'hot': False,
#       'pageviews': 844728},
#      'title': 'Creep',
#      'title_with_featured': 'Creep',
#      'url': 'https://genius.com/Radiohead-creep-lyrics',
#      'primary_artist': {'api_path': '/artists/604',
#       'header_image_url': 'https://images.genius.com/ee4e7ff6b66c73e504d8bce93a39eb30.660x371x1.jpg',
#       'id': 604,
#       'image_url': 'https://images.genius.com/6bcb8629b9b0f55c549d748bdcbca61c.372x372x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Radiohead',
#       'url': 'https://genius.com/artists/Radiohead'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 9,
#      'api_path': '/songs/64344',
#      'full_title': 'Karma Police by\xa0Radiohead',
#      'header_image_thumbnail_url': 'https://images.genius.com/bb8f17187f42bb0b4a0dcc17cad65355.300x300x1.png',
#      'header_image_url': 'https://images.genius.com/bb8f17187f42bb0b4a0dcc17cad65355.1000x1000x1.png',
#      'id': 64344,
#      'lyrics_owner_id': 66760,
#      'lyrics_state': 'complete',
#      'path': '/Radiohead-karma-police-lyrics',
#      'pyongs_count': 56,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/2619451facf786f9d9ff6aef6e9bb178.300x300x1.jpg',
#      'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 309324},
#      'title': 'Karma Police',
#      'title_with_featured': 'Karma Police',
#      'url': 'https://genius.com/Radiohead-karma-police-lyrics',
#      'primary_artist': {'api_path': '/artists/604',
#       'header_image_url': 'https://images.genius.com/ee4e7ff6b66c73e504d8bce93a39eb30.660x371x1.jpg',
#       'id': 604,
#       'image_url': 'https://images.genius.com/6bcb8629b9b0f55c549d748bdcbca61c.372x372x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Radiohead',
#       'url': 'https://genius.com/artists/Radiohead'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 6,
#      'api_path': '/songs/2468344',
#      'full_title': 'Daydreaming by\xa0Radiohead',
#      'header_image_thumbnail_url': 'https://images.genius.com/c9cf30826b50b5096664895e243253ad.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/c9cf30826b50b5096664895e243253ad.1000x1000x1.jpg',
#      'id': 2468344,
#      'lyrics_owner_id': 104344,
#      'lyrics_state': 'complete',
#      'path': '/Radiohead-daydreaming-lyrics',
#      'pyongs_count': 66,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/80f10627decf3f413f1b9ba5fc916e14.300x300x1.jpg',
#      'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 296942},
#      'title': 'Daydreaming',
#      'title_with_featured': 'Daydreaming',
#      'url': 'https://genius.com/Radiohead-daydreaming-lyrics',
#      'primary_artist': {'api_path': '/artists/604',
#       'header_image_url': 'https://images.genius.com/ee4e7ff6b66c73e504d8bce93a39eb30.660x371x1.jpg',
#       'id': 604,
#       'image_url': 'https://images.genius.com/6bcb8629b9b0f55c549d748bdcbca61c.372x372x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Radiohead',
#       'url': 'https://genius.com/artists/Radiohead'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 9,
#      'api_path': '/songs/78831',
#      'full_title': 'Paranoid Android by\xa0Radiohead',
#      'header_image_thumbnail_url': 'https://images.genius.com/bb8f17187f42bb0b4a0dcc17cad65355.300x300x1.png',
#      'header_image_url': 'https://images.genius.com/bb8f17187f42bb0b4a0dcc17cad65355.1000x1000x1.png',
#      'id': 78831,
#      'lyrics_owner_id': 1850,
#      'lyrics_state': 'complete',
#      'path': '/Radiohead-paranoid-android-lyrics',
#      'pyongs_count': 63,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/a68e99a990d4cd010ccaa6aa7bc92848.300x300x1.jpg',
#      'stats': {'unreviewed_annotations': 2,
#       'concurrents': 2,
#       'hot': False,
#       'pageviews': 275329},
#      'title': 'Paranoid Android',
#      'title_with_featured': 'Paranoid Android',
#      'url': 'https://genius.com/Radiohead-paranoid-android-lyrics',
#      'primary_artist': {'api_path': '/artists/604',
#       'header_image_url': 'https://images.genius.com/ee4e7ff6b66c73e504d8bce93a39eb30.660x371x1.jpg',
#       'id': 604,
#       'image_url': 'https://images.genius.com/6bcb8629b9b0f55c549d748bdcbca61c.372x372x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Radiohead',
#       'url': 'https://genius.com/artists/Radiohead'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 7,
#      'api_path': '/songs/71498',
#      'full_title': 'No Surprises by\xa0Radiohead',
#      'header_image_thumbnail_url': 'https://images.genius.com/bb8f17187f42bb0b4a0dcc17cad65355.300x300x1.png',
#      'header_image_url': 'https://images.genius.com/bb8f17187f42bb0b4a0dcc17cad65355.1000x1000x1.png',
#      'id': 71498,
#      'lyrics_owner_id': 94134,
#      'lyrics_state': 'complete',
#      'path': '/Radiohead-no-surprises-lyrics',
#      'pyongs_count': 44,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/ea737061e3342ab50d94932a2d852624.300x300x1.jpg',
#      'stats': {'unreviewed_annotations': 0,
#       'concurrents': 2,
#       'hot': False,
#       'pageviews': 263256},
#      'title': 'No Surprises',
#      'title_with_featured': 'No Surprises',
#      'url': 'https://genius.com/Radiohead-no-surprises-lyrics',
#      'primary_artist': {'api_path': '/artists/604',
#       'header_image_url': 'https://images.genius.com/ee4e7ff6b66c73e504d8bce93a39eb30.660x371x1.jpg',
#       'id': 604,
#       'image_url': 'https://images.genius.com/6bcb8629b9b0f55c549d748bdcbca61c.372x372x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Radiohead',
#       'url': 'https://genius.com/artists/Radiohead'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 11,
#      'api_path': '/songs/2466402',
#      'full_title': 'Burn the Witch by\xa0Radiohead',
#      'header_image_thumbnail_url': 'https://images.genius.com/c9cf30826b50b5096664895e243253ad.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/c9cf30826b50b5096664895e243253ad.1000x1000x1.jpg',
#      'id': 2466402,
#      'lyrics_owner_id': 672397,
#      'lyrics_state': 'complete',
#      'path': '/Radiohead-burn-the-witch-lyrics',
#      'pyongs_count': 56,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/112364bea247e43294b07dad3d7fe528.300x300x1.jpg',
#      'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 235930},
#      'title': 'Burn the Witch',
#      'title_with_featured': 'Burn the Witch',
#      'url': 'https://genius.com/Radiohead-burn-the-witch-lyrics',
#      'primary_artist': {'api_path': '/artists/604',
#       'header_image_url': 'https://images.genius.com/ee4e7ff6b66c73e504d8bce93a39eb30.660x371x1.jpg',
#       'id': 604,
#       'image_url': 'https://images.genius.com/6bcb8629b9b0f55c549d748bdcbca61c.372x372x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Radiohead',
#       'url': 'https://genius.com/artists/Radiohead'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 5,
#      'api_path': '/songs/65925',
#      'full_title': 'All I Need by\xa0Radiohead',
#      'header_image_thumbnail_url': 'https://images.genius.com/f9fc573a95e98a73b8456850f2653b37.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/f9fc573a95e98a73b8456850f2653b37.1000x1000x1.jpg',
#      'id': 65925,
#      'lyrics_owner_id': 11637,
#      'lyrics_state': 'complete',
#      'path': '/Radiohead-all-i-need-lyrics',
#      'pyongs_count': 32,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/f9fc573a95e98a73b8456850f2653b37.300x300x1.jpg',
#      'stats': {'unreviewed_annotations': 2,
#       'concurrents': 2,
#       'hot': False,
#       'pageviews': 210633},
#      'title': 'All I Need',
#      'title_with_featured': 'All I Need',
#      'url': 'https://genius.com/Radiohead-all-i-need-lyrics',
#      'primary_artist': {'api_path': '/artists/604',
#       'header_image_url': 'https://images.genius.com/ee4e7ff6b66c73e504d8bce93a39eb30.660x371x1.jpg',
#       'id': 604,
#       'image_url': 'https://images.genius.com/6bcb8629b9b0f55c549d748bdcbca61c.372x372x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Radiohead',
#       'url': 'https://genius.com/artists/Radiohead'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 6,
#      'api_path': '/songs/66969',
#      'full_title': 'Identikit by\xa0Radiohead',
#      'header_image_thumbnail_url': 'https://images.genius.com/c9cf30826b50b5096664895e243253ad.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/c9cf30826b50b5096664895e243253ad.1000x1000x1.jpg',
#      'id': 66969,
#      'lyrics_owner_id': 76389,
#      'lyrics_state': 'complete',
#      'path': '/Radiohead-identikit-lyrics',
#      'pyongs_count': 30,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/99d27e838881542758f9d8ff092e6302.300x300x1.jpg',
#      'stats': {'unreviewed_annotations': 0,
#       'concurrents': 2,
#       'hot': False,
#       'pageviews': 194392},
#      'title': 'Identikit',
#      'title_with_featured': 'Identikit',
#      'url': 'https://genius.com/Radiohead-identikit-lyrics',
#      'primary_artist': {'api_path': '/artists/604',
#       'header_image_url': 'https://images.genius.com/ee4e7ff6b66c73e504d8bce93a39eb30.660x371x1.jpg',
#       'id': 604,
#       'image_url': 'https://images.genius.com/6bcb8629b9b0f55c549d748bdcbca61c.372x372x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Radiohead',
#       'url': 'https://genius.com/artists/Radiohead'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 11,
#      'api_path': '/songs/1188',
#      'full_title': 'Fake Plastic Trees by\xa0Radiohead',
#      'header_image_thumbnail_url': 'https://images.genius.com/be209037c6eb607ee01d0addcc4f9020.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/be209037c6eb607ee01d0addcc4f9020.1000x1000x1.jpg',
#      'id': 1188,
#      'lyrics_owner_id': 7,
#      'lyrics_state': 'complete',
#      'path': '/Radiohead-fake-plastic-trees-lyrics',
#      'pyongs_count': 44,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/8c0353cde2fdbc687ed6f9ee969e75f2.300x300x1.jpg',
#      'stats': {'unreviewed_annotations': 0,
#       'concurrents': 2,
#       'hot': False,
#       'pageviews': 206494},
#      'title': 'Fake Plastic Trees',
#      'title_with_featured': 'Fake Plastic Trees',
#      'url': 'https://genius.com/Radiohead-fake-plastic-trees-lyrics',
#      'primary_artist': {'api_path': '/artists/604',
#       'header_image_url': 'https://images.genius.com/ee4e7ff6b66c73e504d8bce93a39eb30.660x371x1.jpg',
#       'id': 604,
#       'image_url': 'https://images.genius.com/6bcb8629b9b0f55c549d748bdcbca61c.372x372x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Radiohead',
#       'url': 'https://genius.com/artists/Radiohead'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 13,
#      'api_path': '/songs/107387',
#      'full_title': 'Exit Music (For A Film) by\xa0Radiohead',
#      'header_image_thumbnail_url': 'https://images.genius.com/c327963df7e38c3722b2dd4b6b817e6c.300x300x1.png',
#      'header_image_url': 'https://images.genius.com/c327963df7e38c3722b2dd4b6b817e6c.1000x1000x1.png',
#      'id': 107387,
#      'lyrics_owner_id': 168499,
#      'lyrics_state': 'complete',
#      'path': '/Radiohead-exit-music-for-a-film-lyrics',
#      'pyongs_count': 46,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/c327963df7e38c3722b2dd4b6b817e6c.300x300x1.png',
#      'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 219087},
#      'title': 'Exit Music (For A Film)',
#      'title_with_featured': 'Exit Music (For A Film)',
#      'url': 'https://genius.com/Radiohead-exit-music-for-a-film-lyrics',
#      'primary_artist': {'api_path': '/artists/604',
#       'header_image_url': 'https://images.genius.com/ee4e7ff6b66c73e504d8bce93a39eb30.660x371x1.jpg',
#       'id': 604,
#       'image_url': 'https://images.genius.com/6bcb8629b9b0f55c549d748bdcbca61c.372x372x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Radiohead',
#       'url': 'https://genius.com/artists/Radiohead'}}}]}}

# %% [markdown]
# # urllib3
# HTTP client for Python.
#
# Read the documentation at https://urllib3.readthedocs.io/en/latest/ and seee the GitHub repository at https://github.com/urllib3/urllib3.
#
# Install using:
#
# ```bash
# $ conda install urllib3
# ```
#
# Example request:
#
# ```python
# >>> import urllib3
# >>> http = urllib3.PoolManager()
# >>> r = http.request('GET', 'http://httpbin.org/robots.txt')
# >>> r.status
# 200
# >>> r.data
# 'User-agent: *\nDisallow: /deny\n'
# ```
